# %% [markdown]
# <a href="https://colab.research.google.com/github/timothy-87/Group-1-Tasks/blob/main/Group_1_Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import csv

# %%
with open('bios.csv') as athlete_data:
    reader = csv.reader(athlete_data)
    athlete_data = list(reader)

# %%
athlete_data = pd.read_csv('bios.csv')
athlete_data.head(7)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
# 5           6      Nicolas Chatelain  1970-01-13       Amiens
# 6           7          Patrick Chila  1969-11-27  Ris-Orangis
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# ...

# %%
athlete_data.tail(6)
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145494      149221        George Wright  1890-07-21          Toronto
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145494          Ontario          CAN     Canada      183.0        NaN
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# ...

# %% [markdown]
# ##Creating a dataframe from a csv

# %%
# Reading data in rows from the file
df = pd.read_csv('/content/bios.csv')

# %%
df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df.tail(8)
# Out:
#         athlete_id                   name   born_date           born_city  \
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145494      149221          George Wright  1890-07-21             Toronto
# 145495      149222      Polina Luchnikova  2002-01-30               Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20     Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08              Kotlas
# 145498      149225         André Foussard  1899-05-19               Niort
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 145492   Ciudad de La Habana          CUB       Cuba        NaN        NaN
# 145493  Respublika Tatarstan          RUS        ROC        NaN        NaN
# 145494               Ontario          CAN     Canada      183.0        NaN
# ...

# %%
# Showing columns and datatypes
df.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# athlete_id        int64
# name             object
# born_date        object
# born_city        object
# born_region      object
# born_country     object
# NOC              object
# height_cm       float64
# weight_kg       float64
# died_date        object
# dtype: object

# %% [markdown]
# ## Performing summary statistics and filtering rows and columns

# %%
df.describe()
# Out:
#           athlete_id      height_cm      weight_kg
# count  145500.000000  106651.000000  102070.000000
# mean    73686.188955     176.333724      71.890996
# std     42868.960158      10.380282      14.465540
# min         1.000000     127.000000      25.000000
# 25%     36663.750000     170.000000      62.000000
# 50%     73302.500000     176.000000      70.000000
# 75%    110306.250000     183.000000      80.000000
# max    149814.000000     226.000000     198.000000

# %%
df.describe(include='object')
# Out:
#                name   born_date born_city born_region born_country  \
# count        145500      143693    110908      110908       110908
# unique       142780       41279     22368        2554          236
# top     Ivan Ivanov  1931-01-01  Budapest     England          USA
# freq             13          63      1378        4824         9641
#
#                   NOC   died_date
# count          145499       33940
# unique            696       20009
# top     United States  2002-01-01
# freq            10114          47

# %%
# Filtering columns

# %%
df.born_city
# Out:
# 0                Bordeaux
# 1                  Meulan
# 2                Biarritz
# 3             Paris VIIIe
# 4              Wandsworth
#                ...
# 145495              Serov
# 145496    Moskva (Moscow)
# 145497             Kotlas
# 145498              Niort
# 145499       Dulwich Hill
# Name: born_city, Length: 145500, dtype: object

# %%
df.height_cm
# Out:
# 0           NaN
# 1         183.0
# 2         183.0
# 3         168.0
# 4           NaN
#           ...
# 145495    167.0
# 145496    168.0
# 145497    163.0
# 145498    166.0
# 145499      NaN
# Name: height_cm, Length: 145500, dtype: float64

# %%
df[['NOC', 'born_city']]
# Out:
#               NOC        born_city
# 0          France         Bordeaux
# 1          France           Meulan
# 2          France         Biarritz
# 3          France      Paris VIIIe
# 4          France       Wandsworth
# ...           ...              ...
# 145495        ROC            Serov
# 145496        ROC  Moskva (Moscow)
# 145497        ROC           Kotlas
# 145498     France            Niort
# 145499  Australia     Dulwich Hill
#
# [145500 rows x 2 columns]

# %%
df[['name', 'died_date', 'born_country']]
# Out:
#                          name   died_date born_country
# 0       Jean-François Blanchy  1960-10-02          FRA
# 1              Arnaud Boetsch         NaN          FRA
# 2                Jean Borotra  1994-07-17          FRA
# 3             Jacques Brugnon  1978-03-20          FRA
# 4                Albert Canet  1930-07-25          GBR
# ...                       ...         ...          ...
# 145495      Polina Luchnikova         NaN          RUS
# 145496    Valeriya Merkusheva         NaN          RUS
# 145497        Yuliya Smirnova         NaN          RUS
# 145498         André Foussard  1986-03-18          FRA
# 145499          Bill Phillips  2003-10-20          AUS
#
# [145500 rows x 3 columns]

# %%
# Filtering rows

# %%
df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df[df['born_country']=='FRA']
# Out:
#         athlete_id                   name   born_date    born_city  \
# 0                1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01       Meulan
# 2                3           Jean Borotra  1898-08-13     Biarritz
# 3                4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13       Amiens
# ...            ...                    ...         ...          ...
# 144652      148348          James Clugnet  1996-12-04     Grenoble
# 145009      148720        Margaux Hackett  1999-06-02       Annecy
# 145281      149002         Elliott Baralo  1998-08-01       Annecy
# 145467      149194            Elisa Nakab  1998-05-08     Briançon
# 145498      149225         André Foussard  1899-05-19        Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
# Indexing with iloc

# %%
df.iloc[13]
# Out:
# athlete_id                  14
# name            Étienne Durand
# born_date                  NaN
# born_city                  NaN
# born_region                NaN
# born_country               NaN
# NOC                     France
# height_cm                  NaN
# weight_kg                  NaN
# died_date                  NaN
# Name: 13, dtype: object

# %%
df.iloc[7]
# Out:
# athlete_id                 8
# name            Henri Cochet
# born_date         1901-12-14
# born_city       Villeurbanne
# born_region            Rhône
# born_country             FRA
# NOC                   France
# height_cm                NaN
# weight_kg                NaN
# died_date         1987-04-02
# Name: 7, dtype: object

# %%
df.iloc[7,-1]
# Out:
# '1987-04-02'

# %%
df.iloc[13,6]
# Out:
# 'France'
